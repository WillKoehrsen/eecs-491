# %%
import numpy as np
import pandas as pd

# %%
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.linear_model import LogisticRegressionCV

from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_context('talk')

# %%
df = pd.read_csv('data/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.pairplot(df, hue = 'Outcome', vars = df.columns[:8], diag_kind = 'kde');

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
np.mean(y_test == 0)
# Out:
# 0.66

# %%
print(df.shape)
df.corr()['Outcome']
# Out:
# (768, 9)
# Pregnancies                 0.221898
# Glucose                     0.466581
# BloodPressure               0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# BMI                         0.292695
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
labels = df.Outcome

features_to_use = ['Pregnancies', 'Glucose']
features = features[features_to_use]
X, X_test, y, y_test = train_test_split(features, labels, test_size = 200)

# %%
labels = df.Outcome
features = df.drop(columns = 'Outcome')

X, X_test, y, y_test = train_test_split(features, labels, test_size = 200)

# %%
log_reg = LogisticRegressionCV(Cs = 20, n_jobs = -1)
log_reg.fit(X, y)

predictions = log_reg.predict(X_test)
np.mean(predictions == y_test)
# Out:
# 0.74

# %%
rf = ExtraTreesClassifier(n_estimators = 1000)
rf.fit(X, y)

predictions = rf.predict(X_test)
np.mean(predictions == y_test)
# Out:
# 0.8

# %%
features_exp = features.copy()
features_exp['Outcome'] = labels
sns.pairplot(features_exp, hue = 'Outcome', vars = ['Pregnancies', 'Glucose'], diag_kind = 'kde');

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2)
tc = tsne.fit_transform(df.drop(columns='Outcome'))

# %%
colors = ['red' if outcome == 1 else 'blue' for outcome in labels]
plt.scatter(tc[:, 0], tc[:, 1], color = colors);
